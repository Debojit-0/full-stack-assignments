# %%
#1-
"""the types of the resulting values are list and generator respectively"""
"""l = [n*2 for n in range(1000)] # List comprehension
g = (n*2 for n in range(1000))  # Generator expression"""
# Out:
# 'l = [n*2 for n in range(1000)] # List comprehension\ng = (n*2 for n in range(1000))  # Generator expression'

# %%
#2- a generator is used to create an iterator.
"""-> every generator is an iterator but all iteratior is not an generator.
-> we use iter function in a iterator and yoeld keyword in a genrator.
-> genetaror is an object and iterator is an function
-> yield keyword saves locally in generator
-> in iterator No local variables are used in Iterators"""
# Out:
# '-> every generator is an iterator but all iteratior is not an generator.\n-> we use iter function in a iterator and yoeld keyword in a genrator.\n-> genetaror is an object and iterator is an function\n-> yield keyword saves locally in generator\n-> in iterator No local variables are used in Iterators'

# %%
#3-

"""if the function cintains yield keyowrd its a generator"""
# Out:
# 'if the function cintains yield keyowrd its a generator'

# %%
#4-What indicates that a function is a generator?

# %%
#5- 
"""The map function takes an Expression and an Iterable.
The output will be an Iterable object where the expression will work on each element of the given Iterable.
The output of each expression will be an element of the resultant Iterable."""

# map( expression, iterable) 

"""Python List Comprehension is used for creating a list where each element 
is generated by applying a simple formula to the given list.""" 

# [ expression for item in list if conditional ]
